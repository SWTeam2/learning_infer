# %%
import pickle 
import gzip 

with gzip.open('../data/Test_set/bearing2_6.pkz', 'rb') as f:     
    data = pickle.load(f)

print(data)
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Cell In[5], line 5
#       2 import gzip
#       4 with gzip.open('../data/Test_set/bearing2_6.pkz', 'rb') as f:
# ----> 5     data = pickle.load(f)
#       7 print(data)
#
# File /usr/lib/python3.10/gzip.py:321, in GzipFile.peek(self, n)
#     319     import errno
#     320     raise OSError(errno.EBADF, "peek() on write-only GzipFile object")
# --> 321 return self._buffer.peek(n)
#
# File /usr/lib/python3.10/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /usr/lib/python3.10/gzip.py:488, in _GzipReader.read(self, size)
#     484 if self._new_member:
# ...

# %%
import pandas as pd

obj = pd.read_pickle(r'../data/Test_set/bearing2_6.pkz')

print(obj)

newobj= pd.read_pickle(r'../data/Test_set/bearing1_3_test_data_timestamp.pkz')
print(newobj)
# Out:
#       hour  minute  second  microsecond  horiz accel  vert accel
# 0        8      52      11     618790.0        0.321       0.170
# 1        8      52      11     618830.0       -0.030      -0.542
# 2        8      52      11     618870.0       -0.382       0.027
# 3        8      52      11     618910.0       -0.294       0.319
# 4        8      52      11     618940.0       -0.033       0.485
# ...    ...     ...     ...          ...          ...         ...
# 2555    10      27      21     718590.0       -0.094       0.245
# 2556    10      27      21     718630.0        0.395      -0.130
# 2557    10      27      21     718670.0        0.326      -0.491
# 2558    10      27      21     718710.0        0.116       0.147
# 2559    10      27      21     718750.0       -0.024      -0.495
#
# [1464320 rows x 6 columns]
# ...

# %%
print(newobj)
# Out:
# {'x': array([[[[3.26743895e-04, 4.57232258e-02, 1.59058839e-02, ...,
#           3.02603154e-01, 2.83929980e-02, 8.62440096e-02],
#          [2.57330968e-04, 1.19533612e-02, 4.88892043e-02, ...,
#           5.58071331e-01, 3.82092260e-01, 6.28704267e-02],
#          [1.73222813e-01, 3.08469602e-01, 3.75870081e-01, ...,
#           6.52150306e-01, 1.90092720e-01, 5.58272360e-01],
#          ...,
#          [1.68745230e-02, 3.26372134e-01, 1.82962673e-02, ...,
#           8.18319801e-02, 3.00543209e-02, 2.96124156e-01],
#          [2.43749212e-02, 3.83076690e-01, 3.28904636e-02, ...,
#           1.09460730e-01, 2.22819088e-01, 3.39049911e-02],
#          [3.24617678e-01, 8.80489044e-02, 3.46303532e-01, ...,
#           3.71898311e-01, 4.13198930e-03, 1.10990463e-01]],
#
#         [[6.61099884e-04, 2.19229479e-03, 1.43565409e-03, ...,
#           6.77966259e-03, 1.87813331e-02, 1.15807668e-02],
#          [1.82897059e-02, 4.16964931e-02, 5.86028387e-02, ...,
# ...
